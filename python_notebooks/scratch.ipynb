# %%
import pandas as pd

# %%
cb_df = pd.read_csv('../cerebra_bench/cerebra_giab_all_gencode27_patch_revised.csv', index_col=0)
cb_df
# Out:
#                                                          P3H2  \
# ash_father                                                 []
# ash_mother  ['ENSP00000394326.1:p.(His51=)', 'ENSP00000391...
# ash_son                     ['ENSP00000316881.5:p.(Glu169=)']
# han_father  ['ENSP00000394326.1:p.(His51=)', 'ENSP00000391...
# han_mother  ['ENSP00000394326.1:p.(His51=)', 'ENSP00000391...
# han_son     ['ENSP00000316881.5:p.(His232=)', 'ENSP0000039...
# hap_map     ['ENSP00000394326.1:p.(His51=)', 'ENSP00000391...
#
#                                                          P3H3  \
# ash_father                                                 []
# ash_mother                                                 []
# ash_son                                                    []
# han_father  ['ENSP00000478600.1:p.?', 'ENSP00000478600.1:p...
# han_mother                          ['ENSP00000478600.1:p.?']
# han_son                                                    []
# ...

# %%
cb_df.loc['ash_father']['ANAPC4']
# Out:
# "['ENSP00000426654.1:p.(Phe708=)', 'ENSP00000318775.3:p.(Phe707=)', 'ENSP00000426654.1:p.(Arg466Gln)', 'ENSP00000318775.3:p.(Arg465Gln)']"

# %%
#////////////////////////////////////////////////////////////////////
#////////////////////////////////////////////////////////////////////
#//////     what if i just do all of this with shell    /////////////
#////////////////////////////////////////////////////////////////////

# %%
cereb_ids = pd.read_csv('../cerebra_ash_father_ensp.csv', names=['col'])
funco_ids = pd.read_csv('../funco_bench_ensp_tags/final/ash_father_benchmark_ensp_clean_only_filt_final.vcf', names=['col'])

# %%
set(cereb_ids.col)
set(funco_ids.col)

inter = len(set(cereb_ids.col).intersection(set(funco_ids.col)))

# %%
print(len(set(cereb_ids.col)))
print(len(set(funco_ids.col)))
print(inter)
# Out:
# 23978
# 52724
# 19916
